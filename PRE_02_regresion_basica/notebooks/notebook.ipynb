# %%
# %%
import pandas as pd

dataset = pd.read_csv("../data/auto_mpg.csv")
dataset.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model Year  Origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %%
# %%
# Tamaño del dataset

dataset.shape
# Out:
# (398, 8)

# %%
# %%
# Búsqueda de valores nulos

dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %%
# %%
# Remoción de valores nulos

dataset = dataset.dropna()
dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      0
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %%
# %%
# Columna Origin
# Nota:  1) USA
#        2) Europe
#        3) Japan

dataset.Origin.value_counts()
dataset.head(20)
# Out:
#      MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0   18.0          8         307.0       130.0  3504.0          12.0
# 1   15.0          8         350.0       165.0  3693.0          11.5
# 2   18.0          8         318.0       150.0  3436.0          11.0
# 3   16.0          8         304.0       150.0  3433.0          12.0
# 4   17.0          8         302.0       140.0  3449.0          10.5
# 5   15.0          8         429.0       198.0  4341.0          10.0
# 6   14.0          8         454.0       220.0  4354.0           9.0
# 7   14.0          8         440.0       215.0  4312.0           8.5
# 8   14.0          8         455.0       225.0  4425.0          10.0
# 9   15.0          8         390.0       190.0  3850.0           8.5
# 10  15.0          8         383.0       170.0  3563.0          10.0
# 11  14.0          8         340.0       160.0  3609.0           8.0
# 12  15.0          8         400.0       150.0  3761.0           9.5
# 13  14.0          8         455.0       225.0  3086.0          10.0
# 14  24.0          4         113.0        95.0  2372.0          15.0
# 15  22.0          6         198.0        95.0  2833.0          15.5
# 16  18.0          6         199.0        97.0  2774.0          15.5
# 17  21.0          6         200.0        85.0  2587.0          16.0
# 18  27.0          4          97.0        88.0  2130.0          14.5
# 19  26.0          4          97.0        46.0  1835.0          20.5
#
#     Model Year  Origin
# 0           70       1
# 1           70       1
# 2           70       1
# 3           70       1
# 4           70       1
# 5           70       1
# 6           70       1
# 7           70       1
# 8           70       1
# 9           70       1
# 10          70       1
# 11          70       1
# 12          70       1
# 13          70       1
# 14          70       3
# 15          70       1
# 16          70       1
# 17          70       1
# 18          70       3
# 19          70       2

# %%
# %%
# Genera variables dummy para indicar la procedencia (Pésima solución)

dataset = pd.get_dummies(dataset, columns=["Origin"], prefix="", prefix_sep="")
dataset.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model Year     1      2      3
# 0          70  True  False  False
# 1          70  True  False  False
# 2          70  True  False  False
# 3          70  True  False  False
# 4          70  True  False  False

# %%
# Note que aca no se usa train_test_split

train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %%
# Las millas por galon (MPG) son función de las demas variables.

import seaborn as sns

sns.pairplot(
    train_dataset[["MPG", "Cylinders", "Displacement", "Weight"]], diag_kind="kde"
)
# Out:
# /home/daxx/Documentos/GitHub/std-david-fuentes-carrillo/.venv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/daxx/Documentos/GitHub/std-david-fuentes-carrillo/.venv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/daxx/Documentos/GitHub/std-david-fuentes-carrillo/.venv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/daxx/Documentos/GitHub/std-david-fuentes-carrillo/.venv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
